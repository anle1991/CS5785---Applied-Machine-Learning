# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### c) Plot the loss over time, after letting it run for 5,000 iterations. How good does the network eventually get?

# %%
loss = np.loadtxt('./data/5000_loss.txt')

# %%
plt.plot(loss, linewidth=2)
plt.ylabel('Loss')
plt.xlabel('Iteration')
plt.yticks(np.arange(min(loss),max(loss), 0.01))
plt.grid()

# %% [markdown]
# ### d) Can you make the network converge to a lower loss function by lowering the learning rate every 1,000 iterations? (Some learning rate schedules, for example, halve the learning rate every n iterations. Does this technique let the network converge to a lower training loss?)

# %%
loss_1k = np.loadtxt('./data/5000_1k_loss.txt')

# %%
plt.plot(loss_1k, linewidth=2)
plt.ylabel('Loss')
plt.xlabel('Iteration')
plt.yticks(np.arange(min(loss),max(loss), 0.01))
plt.grid()

# %% [markdown]
# ### e)Lesionstudy.ThetextboxcontainsasmallsnippetofJavascriptcodethatinitializesthenet- work. You can change the network structure by clicking the “Reload network” button, which simply evaluates the code. Let’s perform some brain surgery: Try commenting out each layer, one by one. Report some results: How many layers can you drop before the accuracy drops below a useful value? How few hidden units can you get away with before quality drops no- ticeably?

# %%
sixlayer = np.loadtxt('./data/6_layer.txt')
fivelayer = np.loadtxt('./data/5_layer.txt')
fourlayer = np.loadtxt('./data/4_layer.txt')
threelayer = np.loadtxt('./data/3_layer.txt')
onelayer = np.loadtxt('./data/1_layer.txt')

# %%
plt.plot(loss, linewidth=2, color='r', label='7 layers')
plt.plot(sixlayer, linewidth=2, color='g', label='6 layers')
plt.plot(fivelayer, linewidth=2, color='b', label='5 layers')
plt.plot(fourlayer, linewidth=2, color='y', label='4 layers')
plt.plot(threelayer, linewidth=2, color='b', label='3 layers')
plt.plot(onelayer, linewidth=2, color='orange', label='1 layers')
plt.ylabel('Loss')
plt.xlabel('Iteration')
plt.legend()
plt.grid()

# %%
hiddenlay_15 = np.loadtxt('./data/hiddenlayer_15.txt')
hiddenlay_13 = np.loadtxt('./data/hiddenlayer_13.txt')

plt.semilogy(loss, linewidth=2, color='r', label='20 layers')
plt.semilogy(hiddenlay_15, linewidth=2, color='orange', label='15 layers')
plt.semilogy(hiddenlay_13, linewidth=2, color='b', label='13 layers')
plt.ylabel('Loss')
plt.xlabel('Iteration')
plt.ylim((3e-3, 1.5e-1))
plt.legend()
plt.grid()

# %% [markdown]
# ### f) Try adding a few layers by copy+pasting lines in the network definition. Can you noticeably increase the accuracy of the network?

# %%
tenlayer = np.loadtxt('./data/10_layer.txt')
twelvelayer = np.loadtxt('./data/12_layer.txt')

plt.semilogy(loss, linewidth=2, color='r', label='7 layers')
plt.semilogy(tenlayer, linewidth=2, color='g', label='10 layers')
plt.semilogy(twelvelayer, linewidth=2, color='b', label='12 layers')

plt.ylabel('Loss')
plt.xlabel('Iteration')
plt.ylim((3e-3, 1.5e-1))
plt.legend()
plt.grid()
